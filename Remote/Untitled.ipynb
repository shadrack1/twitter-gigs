# %%
import pandas as pd
df=pd.read_csv("tweets.csv")

# %%
df
# Out:
#                       id      conversation_id     created_at        date  \
# 0    1245499506206048258  1245499506206048258  1585785197000  2020-04-02
# 1    1245497179269033984  1245497179269033984  1585784642000  2020-04-02
# 2    1245495307011600384  1245429688996151296  1585784196000  2020-04-02
# 3    1245494563478749184  1245494563478749184  1585784018000  2020-04-02
# 4    1245493979992522756  1245493979992522756  1585783879000  2020-04-02
# ..                   ...                  ...            ...         ...
# 685  1244789201641578500  1244789201641578500  1585615847000  2020-03-31
# 686  1244788085185019904  1244788085185019904  1585615581000  2020-03-31
# 687  1244782280167567361  1244782280167567361  1585614197000  2020-03-31
# 688  1244782217311780864  1244782217311780864  1585614182000  2020-03-31
# 689  1244776426026545153  1244776426026545153  1585612801000  2020-03-31
#
#          time              timezone              user_id         username  \
# ...

# %%
pd.size
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-da1843de88a2> in <module>
# ----> 1 pd.size
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\__init__.py in __getattr__(name)
#     261             return _SparseArray
#     262
# --> 263         raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     264
#     265
#
# AttributeError: module 'pandas' has no attribute 'size'

# %%
pd.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-8e58767ddcd1> in <module>
# ----> 1 pd.shape
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\__init__.py in __getattr__(name)
#     261             return _SparseArray
#     262
# --> 263         raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     264
#     265
#
# AttributeError: module 'pandas' has no attribute 'shape'

# %%
df.shape
# Out:
# (690, 34)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 690 entries, 0 to 689
# Data columns (total 34 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               690 non-null    int64
#  1   conversation_id  690 non-null    int64
#  2   created_at       690 non-null    int64
#  3   date             690 non-null    object
#  4   time             690 non-null    object
#  5   timezone         690 non-null    object
#  6   user_id          690 non-null    int64
#  7   username         690 non-null    object
#  8   name             690 non-null    object
#  9   place            0 non-null      float64
#  10  tweet            690 non-null    object
#  11  mentions         690 non-null    object
#  12  urls             690 non-null    object
#  13  photos           690 non-null    object
#  14  replies_count    690 non-null    int64
#  15  retweets_count   690 non-null    int64
#  16  likes_count      690 non-null    int64
# ...

# %%
pd.set_option('display.max_columns', 34)

# %%
df.columns
# Out:
# Index(['id', 'conversation_id', 'created_at', 'date', 'time', 'timezone',
#        'user_id', 'username', 'name', 'place', 'tweet', 'mentions', 'urls',
#        'photos', 'replies_count', 'retweets_count', 'likes_count', 'hashtags',
#        'cashtags', 'link', 'retweet', 'quote_url', 'video', 'near', 'geo',
#        'source', 'user_rt_id', 'user_rt', 'retweet_id', 'reply_to',
#        'retweet_date', 'translate', 'trans_src', 'trans_dest'],
#       dtype='object')

# %%
print(df['username'])
# Out:
# 0      remote_dev_jobs
# 1          ttengineer1
# 2        2020_oklahoma
# 3          postjobfree
# 4         remotepeople
#             ...
# 685        remoteboxio
# 686         heyangela6
# 687    remote_dev_jobs
# 688           dvlpdnvr
# 689       jobsincrypto
# Name: username, Length: 690, dtype: object

# %%
print(df[['username', 'name', 'tweet', 'mentions']])
# Out:
#             username                             name  \
# 0    remote_dev_jobs            Remote Developer Jobs
# 1        ttengineer1                      TTEngineer1
# 2      2020_oklahoma  🌹🍞 quarantine band time 🌈💞💞☭Ⓐ🎼👽
# 3        postjobfree                    Post Job Free
# 4       remotepeople                      Remote Jobs
# ..               ...                              ...
# 685      remoteboxio                        RemoteBox
# 686       heyangela6                           Angela
# 687  remote_dev_jobs            Remote Developer Jobs
# 688         dvlpdnvr                         dvlpdnvr
# 689     jobsincrypto              Cryptocurrency Jobs
#
#                                                  tweet  \
# 0    Senior Web Architect (.NET / Javascript) at Ar...
# 1    Sounds like the DNC and Sleepy Joe are putting...
# 2    And honestly the books may feel like games bec...
# 3    Sr Python Developer with AWS Stack in Agoura H...
# ...

# %%
for index, row in df.iterrows():
    print(index, row['tweet'])
# Out:
# 0 Senior Web Architect (.NET / Javascript) at Arcanys 👇 https://www.remote-developer-jobs.com/job/243370/
# 1 Sounds like the DNC and Sleepy Joe are putting plans in place to rig the election —> Biden: States Should Prepare for Remote Voting in 2020 Elections  https://www.breitbart.com/clips/2020/03/31/biden-states-should-prepare-for-remote-voting-in-2020-elections/ …
# 2 And honestly the books may feel like games because he's also a developer I think, so maybe there will be a pretty good AA game (not like an ea cash grab)
# 3 Sr Python Developer with AWS Stack in Agoura Hills, CA: c2c, jd, mortgage, remote  https://postjobfree.com/job/iqh466
# 4 If you plan to work as a Full Stack Developer - MEAN, Curotec is hiring.  #node.js #mongodb #angularjs #html #javascript  https://remotepeople.io/jobs/detail/F83sa8sQo-full-stack-developer-mean … #remote
# ...

# %%
df.describe()
# Out:
#                  id  conversation_id    created_at       user_id  place  \
# count  6.900000e+02     6.900000e+02  6.900000e+02  6.900000e+02    0.0
# mean   1.245162e+18     1.245113e+18  1.585705e+12  5.694220e+17    NaN
# std    2.080412e+14     7.942694e+14  4.960089e+07  5.406971e+17    NaN
# min    1.244776e+18     1.225903e+18  1.585613e+12  6.501230e+05    NaN
# 25%    1.244995e+18     1.244992e+18  1.585665e+12  8.386344e+08    NaN
# 50%    1.245111e+18     1.245106e+18  1.585693e+12  8.110634e+17    NaN
# 75%    1.245363e+18     1.245360e+18  1.585753e+12  1.101083e+18    NaN
# max    1.245500e+18     1.245500e+18  1.585785e+12  1.245032e+18    NaN
#
#        replies_count  retweets_count  likes_count       video  near  geo  \
# count     690.000000      690.000000   690.000000  690.000000   0.0  0.0
# mean        0.185507        1.566667     2.014493    0.005797   NaN  NaN
# std         1.075020       13.375748    15.337228    0.075973   NaN  NaN
# ...

# %%
df.head(10)
# Out:
#          date              timezone         username  \
# 0  2020-04-02  Arabic Standard Time  remote_dev_jobs
# 1  2020-04-02  Arabic Standard Time      ttengineer1
# 2  2020-04-02  Arabic Standard Time    2020_oklahoma
# 3  2020-04-02  Arabic Standard Time      postjobfree
# 4  2020-04-02  Arabic Standard Time     remotepeople
# 5  2020-04-02  Arabic Standard Time     matthewtrask
# 6  2020-04-02  Arabic Standard Time  remote_dev_jobs
# 7  2020-04-02  Arabic Standard Time      jobhookup4u
# 8  2020-04-02  Arabic Standard Time   noknow80094321
# 9  2020-04-02  Arabic Standard Time       ropopurist
#
#                               name  \
# 0            Remote Developer Jobs
# 1                      TTEngineer1
# 2  🌹🍞 quarantine band time 🌈💞💞☭Ⓐ🎼👽
# 3                    Post Job Free
# 4                      Remote Jobs
# 5                       matt trask
# 6            Remote Developer Jobs
# 7                     Kirsten Barr
# 8         noknow@nomad in Cyprus🇨🇾
# ...

# %%
df.columns
# Out:
# Index(['date', 'timezone', 'username', 'name', 'tweet', 'photos', 'cashtags',
#        'retweet_date'],
#       dtype='object')

# %%
df = df.drop(columns=['cashtags', 'retweet_date'])
